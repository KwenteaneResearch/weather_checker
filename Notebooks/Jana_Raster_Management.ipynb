# %% [markdown]
# Read GeoTIFF

# %%
#pip install rasterio
# Out:
# Collecting rasterio
#   Using cached rasterio-1.3.9-cp310-cp310-manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting affine (from rasterio)
#   Using cached affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /home/jana/.pyenv/versions/3.10.6/envs/weather_checker/lib/python3.10/site-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /home/jana/.pyenv/versions/3.10.6/envs/weather_checker/lib/python3.10/site-packages (from rasterio) (2024.2.2)
# Requirement already satisfied: click>=4.0 in /home/jana/.pyenv/versions/3.10.6/envs/weather_checker/lib/python3.10/site-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /home/jana/.pyenv/versions/3.10.6/envs/weather_checker/lib/python3.10/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /home/jana/.pyenv/versions/3.10.6/envs/weather_checker/lib/python3.10/site-packages (from rasterio) (1.26.3)
# Collecting snuggs>=1.4.1 (from rasterio)
#   Using cached snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /home/jana/.pyenv/versions/3.10.6/envs/weather_checker/lib/python3.10/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /home/jana/.pyenv/versions/3.10.6/envs/weather_checker/lib/python3.10/site-packages (from rasterio) (63.2.0)
# Requirement already satisfied: pyparsing>=2.1.6 in /home/jana/.pyenv/versions/3.10.6/envs/weather_checker/lib/python3.10/site-packages (from snuggs>=1.4.1->rasterio) (3.1.1)
# Using cached rasterio-1.3.9-cp310-cp310-manylinux2014_x86_64.whl (20.6 MB)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.3.9 snuggs-1.4.7
# Note: you may need to restart the kernel to use updated packages.

# %%
from osgeo import gdal, ogr
import geopandas as gpd
import matplotlib.pyplot as plt

import rasterio
from rasterio.plot import show

import numpy as np
from sklearn.cluster import KMeans
#import gdal
import pandas as pd

# %%
#path="test\cacao\masked\mask_spam2017V2r1_SSA_A_COCO_A.tif"

# %%
#set path to image
path="mask_spam2017V2r1_SSA_A_COCO_A.tif"

# %%
#Define Functions

def Bounding_Box(tiff_file, geometry_name='geometry'):

    # Get transformation
    transform = tiff_file.GetGeoTransform()

    # Create a geometry representing the bounding box
    minx, miny = transform[0], transform[3] + tiff_file.RasterYSize * transform[5]
    maxx, maxy = transform[0] + tiff_file.RasterXSize * transform[1], transform[3]

    # Create a polygon from the bounding box using ogr
    ring = ogr.Geometry(ogr.wkbLinearRing)
    ring.AddPoint(minx, miny)
    ring.AddPoint(minx, maxy)
    ring.AddPoint(maxx, maxy)
    ring.AddPoint(maxx, miny)
    ring.AddPoint(minx, miny)

    polygon = ogr.Geometry(ogr.wkbPolygon)
    polygon.AddGeometry(ring)

    # Create a GeoDataFrame from the ogr geometry
    gdf = gpd.GeoDataFrame(geometry=[polygon], crs=tiff_file.GetProjection())

    # Close the gdal dataset
    dataset = None

    return gdf

# %%
#open Dataset with GDAL
dataset = gdal.Open(path)
dataset
# Out:
# <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0x7f23bbfbe220> >

# %%
#plot it :)

# %%
# Read the raster data
data = dataset.ReadAsArray()

# Plot the raster data using matplotlib
plt.imshow(data, cmap='viridis')
plt.title('COCO_AREA')
plt.colorbar(label='AREA')
plt.show()

# %%
#Alternatively Open IMage with rasterio
dataset_rasterio = rasterio.open(path)

# %%
# Plot it
show(dataset_rasterio, cmap='viridis', title='COCO_AREA')
plt.show()

# %%
def K_means_images(dataset, n_clusters, best_classes):
    # Read the raster data
    data = dataset.read()

    # Reshape to one channel
    reshaped_data = data.reshape(-1, 1)

    # k-means clustering 
    #n_clusters = 6
    kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(reshaped_data)
    cluster_labels = kmeans.labels_
    
    # Reshape the clustered labels back to the original image shape
    clustered_image = cluster_labels.reshape(data.shape)
    
    # Find the two most dominant clusters
    dominant_clusters = np.argsort(np.bincount(cluster_labels))[::-1][:2]
    '''didnt added best_classes, as value to control the count of the best taken classes'''

    # Mask the image to keep only pixels corresponding to the two dominant clusters
    masked_image = np.where(np.isin(clustered_image, dominant_clusters), clustered_image, np.nan)

    # Squeeze dimension in the data array
    #data_squeezed = np.squeeze(data)

    # Return both Images
    return data, clustered_image, masked_image

# %%
#call k_means_images
original, kmeans, best = K_means_images(dataset_rasterio,6,2)

# %%
#lets plot it 

# Plot the original and clustered images side by side
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12,6))

# Original image
show(data, ax=ax1, cmap='viridis', title='Original Image')

# Clustered image
show(kmeans, ax=ax2, cmap='viridis', title='K-Means Clustering (k=6)')

# masked image
show(best, ax=ax3, cmap='viridis', title='Two dominant classes')

# Add colorbar 
cbar = fig.colorbar(ax3.images[0], ax=ax3, orientation='vertical', fraction=0.046, pad=0.04)
cbar.set_label('')

plt.tight_layout()
plt.show()


#plt.show()

# %%
def get_centroids_geotiff(dataset):
 
    # Get the geotransform parameters
    geotransform = dataset.GetGeoTransform()
    top_left_x, pixel_width, _, top_left_y, _, pixel_height = geotransform

    # Get number of rows and columns 
    rows, cols = dataset.RasterYSize, dataset.RasterXSize

    # lists to store centroid coordinates
    centroids_x = []
    centroids_y = []

    # Calculate centroids for each pixel
    for i in range(rows):
        for j in range(cols):
            centroid_x = top_left_x + j * pixel_width + pixel_width / 2.0
            centroid_y = top_left_y + i * pixel_height + pixel_height / 2.0
            centroids_x.append(centroid_x)
            centroids_y.append(centroid_y)

    # Convert to NumPy arrays
    centroids_x = np.array(centroids_x)
    centroids_y = np.array(centroids_y)

    # Create a DataFrame
    df = pd.DataFrame({'Centroid_X': centroids_x, 'Centroid_Y': centroids_y})

    dataset = None

    return df

# %%
# Example
centroids = get_centroids_geotiff(dataset)
print(centroids_df.head())
# Out:
#    Centroid_X  Centroid_Y
# 0   -8.542352   10.625317
# 1   -8.459019   10.625317
# 2   -8.375686   10.625317
# 3   -8.292353   10.625317
# 4   -8.209020   10.625317

# %%
def centroids_to_dataframe(centroids_df, clustered_image, original_image):

    # Get the coordinates of centroids
    centroid_coords = centroids_df[['Centroid_X', 'Centroid_Y']].values

    # Convert centroid coordinates to integers
    centroid_coords = centroid_coords.astype(int)

    # Get the original values corresponding to centroids
    original_values = original_image[centroid_coords[:, 1], centroid_coords[:, 0]]

    # Get the class labels corresponding to centroids
    class_labels = clustered_image[centroid_coords[:, 1], centroid_coords[:, 0]]

    # Add original values and class labels to the centroids DataFrame
    centroids_df['Original_Value'] = original_values
    centroids_df['Class_Label'] = class_labels

    return centroids_df

# %%
def setup_dataframe(centroids_df, data, clustered_image):

    # Get centroid coordinates
    centroid_coords = centroids_df[['Centroid_X', 'Centroid_Y']].values

    # Convert centroid coordinates to integer indices
    centroid_coords_int = centroid_coords.astype(int)

    # Get original values corresponding to centroid coordinates
    original_values = data[centroid_coords_int[:, 1], centroid_coords_int[:, 0]]

    # Get class labels corresponding to centroid coordinates
    class_labels = clustered_image[centroid_coords_int[:, 1], centroid_coords_int[:, 0]]

    # Create DataFrame with centroid coordinates, original values, and class labels
    df = pd.DataFrame({
        'Centroid_X': centroids_df['Centroid_X'],
        'Centroid_Y': centroids_df['Centroid_Y'],
        'Original_Value': original_values,
        'Class_Label': class_labels
    })

    return df

# %%
test1=setup_dataframe(centroids, data, kmeans)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 test1=setup_dataframe(centroids, data, kmeans)
#
# Cell In[128], line 13, in setup_dataframe(centroids_df, data, clustered_image)
#      10 original_values = data[centroid_coords_int[:, 1], centroid_coords_int[:, 0]]
#      12 # Get class labels corresponding to centroid coordinates
# ---> 13 class_labels = clustered_image[centroid_coords_int[:, 1], centroid_coords_int[:, 0]]
#      15 # Create DataFrame with centroid coordinates, original values, and class labels
#      16 df = pd.DataFrame({
#      17     'Centroid_X': centroids_df['Centroid_X'],
#      18     'Centroid_Y': centroids_df['Centroid_Y'],
#      19     'Original_Value': original_values,
#      20     'Class_Label': class_labels
#      21 })
#
# IndexError: index 10 is out of bounds for axis 0 with size 1

# %%
test=centroids_to_dataframe(centroids, kmeans, data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 test=centroids_to_dataframe(centroids, kmeans, data)
#
# Cell In[113], line 10, in centroids_to_dataframe(centroids_df, kmeans, original_image)
#       7 centroid_coords = centroids_df[['Centroid_X', 'Centroid_Y']].values
#       9 # Predict class labels for centroids using the fitted KMeans object
# ---> 10 class_labels = kmeans.predict(centroid_coords)
#      12 # Get the original values corresponding to centroids
#      13 original_values = original_image[centroid_coords[:, 1].astype(int), centroid_coords[:, 0].astype(int)]
#
# File ~/.pyenv/versions/3.10.6/envs/weather_checker/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1100, in _BaseKMeans.predict(self, X, sample_weight)
#    1074 """Predict the closest cluster each sample in X belongs to.
#    1075
#    1076 In the vector quantization literature, `cluster_centers_` is called
#    (...)
#    1096     Index of the cluster each sample belongs to.
#    1097 """
#    1098 check_is_fitted(self)
# -> 1100 X = self._check_test_data(X)
#    1101 if not (isinstance(sample_weight, str) and sample_weight == "deprecated"):
#    1102     warnings.warn(
#    1103         (
#    1104             "'sample_weight' was deprecated in version 1.3 and "
#    (...)
#    1107         FutureWarning,
#    1108     )
#
# File ~/.pyenv/versions/3.10.6/envs/weather_checker/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:952, in _BaseKMeans._check_test_data(self, X)
#     951 def _check_test_data(self, X):
# --> 952     X = self._validate_data(
#     953         X,
#     954         accept_sparse="csr",
#     955         reset=False,
#     956         dtype=[np.float64, np.float32],
#     957         order="C",
#     958         accept_large_sparse=False,
#     959     )
#     960     return X
#
# File ~/.pyenv/versions/3.10.6/envs/weather_checker/lib/python3.10/site-packages/sklearn/base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File ~/.pyenv/versions/3.10.6/envs/weather_checker/lib/python3.10/site-packages/sklearn/base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 2 features, but KMeans is expecting 73 features as input.
